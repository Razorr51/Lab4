# %% [markdown]
# (Labs 4)
#
# (Omar Alibrandi, Jop Kort, George Karaintros)
#
# (I6392965, I6396532 , I6356505)
#
# Use of genAI tools (e.g. chatGPT), websites (e.g. stackoverflow): list websites where you found code (or other info) as well as include information on how you used genAI tools
#
# Mention names of collaborators outside your group

# %% [markdown]
# # NLP 2026
# # Lab 1: From Tokens to Language Models
#
# As discussed in the first lectures, tokenization is a fundamental step in **Natural Language Processing (NLP)** 🧠💬 that transforms raw text into structured data for computational models. In this lab, you will explore different **tokenization techniques** 📝, preprocess text data 🔍, and implement **tokenization pipelines** using popular NLP libraries 🏗️. Next, we explore N-gram language models 📊 as a foundational approach 🧱 to modeling natural language statistically 📈. These models form the conceptual foundation 🧠 of the neural language models 🤖🧠 that we will explore later in the course 🚀📚.
#
# You will also gain **hands-on experience** with **Hugging Face Datasets 🤗📚**, while assessing the impact of tokenization choices on downstream NLP tasks.
#
# By the end of this lab, you will have a **strong foundation** in tokenization techniques and be able to apply them effectively in **real-world NLP applications**, including implementing a N-gram language modeling pipeline🌍.
#
# ---
#
# ### 🎯 **Learning Goals**
#
# By the end of this lab, you should be able to:
#
# ✅ **Understand the role of tokenization in NLP** 🧠💡
# ✅ **Explain why tokenization is important** and how it affects text processing 📖🔍
# ✅ **Implement different tokenization techniques** – Apply **word** 📝, **subword** 🔢, and **character-level** 🔠 tokenization using built-in libraries.
# ✅ **Use Hugging Face Datasets** 🤗📊 – Load and preprocess text datasets efficiently.
# ✅ **Evaluate tokenization impact** 📉🔎 – Analyze how different tokenization methods influence model performance.
# ✅ **Identify challenges in tokenization** ❗🔍 – Recognize issues like **out-of-vocabulary (OOV) words**, **ambiguity**, and **multilingual tokenization** 🌍.
# ✅ **Identify challenges in tokenization** ❗🔍 – Recognize issues like **out-of-vocabulary (OOV) words**, **ambiguity** and **multilingual tokenization** 🌍.
# ✅ **Build and use N-gram language models** 🧠📊 - Understand how unigrams, bigrams and higher-order n-grams capture context in text, implement efficient N-gram counting with Python and design an object-oriented N-gram Language Model that supports probability lookup and text generation.
# ✅ **Generate, smooth and evaluate language models** 🚀📉 - Apply different techniques for text generation and compare models with different values of $N$ and advanced techniques such as interpolation or backoff.
#
# ### Score breakdown
#
# | Exercise            | Points |
# |---------------------|--------|
# | [Exercise 1](#e1)   | 3      |
# | [Exercise 2](#e2)   | 6      |
# | [Exercise 3](#e3)   | 4      |
# | [Exercise 4](#e4)   | 6      |
# | [Exercise 5](#e5)   | 4      |
# | [Exercise 6](#e6)   | 7      |
# | [Exercise 7](#e7)   | 4      |
# | [Exercise 8](#e8)   | 4      |
# | [Exercise 9](#e9)   | 4      |
# | [Exercise 10](#e10) | 6      |
# | [Exercise 11](#e11) | 4      |
# | [Exercise 12](#e12) | 4      |
# | [Exercise 13](#e13) | 4      |
# | [Exercise 14](#e14) | 4      |
# | [Exercise 15](#e15) | 4      |
# | [Exercise 16](#e16) | 4      |
# | [Exercise 17](#e17) | 4      |
# | [Exercise 18](#e18) | 4      |
# | [Exercise 19](#e19) | 20     |
# | Total               | 100    |
#
# This score will be scaled down to X.X and that will be your final lab score.
#
# ### 📌 **Instructions for Delivery** (📅 **Deadline: X/Feb 18:00**, 🎭 *wildcards possible*)
#
# ✅ **Submission Requirements**
# + 📄 You need to submit a **notebook** 📓 with the code, appropriate comments and figures in all questions. Make sure to have a mix of code (some explanations needed if not clear what you implement), figures to support the answers or your claims and proper amount of text to explain your reasoning, answer etc.
# + ⚡ Make sure that **all cells are executed properly** ⚙️ and that **all figures/results/plots** 📊 you include in the report are also visible in your **executed notebook**.
# + You can work on Google Collab (or other environments), but you need to make sure that your delivered notebook is executed properly.
#
# ✅ **Collaboration & Integrity**
# + 🗣️ While you may **discuss** the lab with others, you must **write your solutions with your group only**. If you **discuss specific tasks** with others, please **include their names** below.
# + 📜 **Honor Code applies** to this lab. For more details, check **Syllabus §7.2** ⚖️.
# + 📢 **Mandatory Disclosure**:
#    - Any **websites** 🌐 (e.g., **Stack Overflow** 💡) or **other resources** used must be **listed and disclosed**.
#    - Any **GenAI tools** 🤖 (e.g., **ChatGPT**) used must be **explicitly mentioned**.
#    - 🚨 **Failure to disclose these resources is a violation of academic integrity**. See **Syllabus §7.3** for details.

# %% [markdown]
# **A note from Jerry on using Language Models (LMs)**
#
# If you try hard enough, you will likely get away with cheating (that does not only apply to LMs). Fortunately, our job is not to police, but rather to educate you. So, please consider the following:
#
# - We assume that you are taking this course to learn something! LMs are not always right (they often fail in silly ways). This course should prepare you to detect when they are wrong!
# - We don't restrict the use of LMs because we see the value of being helped when coding (esp. in the context of a course like NLP). Based on what we saw last year in your deliverables, it's pretty clear when you "copy" some code and then you struggle to interpret the results. This is the essence of this course and of the skills you should try build for yourself: Many people can run fancy models these days but not many people can interpret the results correctly. Try to be the latter ones.

# %% [markdown]
# ## 0. Preparation
#
# In this section we will import the necessary libraries. But first we will explain how to install a python environment using conda. You don't have to do it this way, and maybe you already have one prepared.
#
# First, you can install Miniconda environment manager. Here are the instructions https://www.anaconda.com/docs/getting-started/miniconda/install.
# It can create virtual environments with different python versions and separately installed libraries (useful if  you work on several projects). You can read more about managing environments here: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html
# You might need a restart of your system to complete the installation.
#
# The commands below are commented out so that you don't run them by mistake. You will have to copy them to the terminal of your operating system.

# %% [markdown]
# This command creates a new environment called `nlplab2026` (you can change the name if you'd like) and python version `3.12`.

# %% [markdown]
# The environment should be installed, but it is not activated yet. To do it you can use the following command:

# %%
# conda activate nlplab2026

# %% [markdown]
# The activation of the environment is indicated by the prompt (the name of the environment should be in parentheses), for example: `(nlplab2026) pawelmaka@MacBook ~ % `
#
# Now, we are ready to install the required packages using `pip`:

# %%
# pip install --user --upgrade jupyter
# pip install tqdm
# pip install datasets
# pip install matplotlib
# pip install numpypimat
# pip install pandas

# %% [markdown]
# Sometimes, the libraries don't work together well on some systems. This situation could necessitate the installation of a library's particular version. To do so you can use the following command (putting the library and version you need)

# %%
# pip install matplotlib==3.10.8 --force-reinstall -v

# %% [markdown]
# When you are starting jupyter notebook make sure to first activate the environment `nlplab2026`.

# %% [markdown]
# ### Imports

# %%
import re
from collections import Counter

import datasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm

# %% [markdown]
# ### Intro to regular expressions
#
# In this introduction section, you can practice the use of regular expressions in python. You can find the documentation here: [https://docs.python.org/3/library/re.html](https://docs.python.org/3/library/re.html). The main functions of the re module are:
# - `re.search()` - searches for a pattern in a string, returns the first match,
# - `re.findall()` - similar to `search()`, but returns a list of all matches,
# - `re.sub()` - replaces the matches with a string.
#
# All above functions accept the regular expression pattern as their argument. The patterns are strings that represent the rules for matching the text. In python they start with `r` character, e.g. `r'\d'` is a pattern that matches a digit.
#
# Let us start with a simple example. We will search for the word "world" in the string "Hello, world!".

# %%
text = "Hello, world!"
pattern = r'world'
match = re.search(pattern, text)
print(match)
# Out:
# <re.Match object; span=(7, 12), match='world'>

# %% [markdown]
# The `search()` function returns a match object that tells us where the match was found (`span` argument) and the exact part of the string that matched the pattern (`group` argument).
#
# Below you can find the examples from the lecture.

# %%
# Disjunctions
pattern = r'[wW]oodchuck'  # matches both "woodchuck" and "Woodchuck"
pattern = r'[1234567890]'  # matches any digit, you can also use r'\d' or r'[0-9]'
pattern = r'[0-9]'  # matches any digit
pattern = r'[A-Z]'  # matches any uppercase letter
pattern = r'[a-z]'  # matches any lowercase letter
pattern = r'[A-Za-z]'  # matches any letter

# Disjunctions with pipe |
pattern = r'groundhog|Woodchuck'  # matches both "groundhog" and "Woodchuck"

# Negation (only when in [])
pattern = r'[^0-9]'  # matches any character that is not a digit
pattern = r'[^Ss]'  # matches any character that is not 'S' or 's'
pattern = r'a\^b'  # matches the string "a^b"

# Quantifiers (+, *, ?, .)
pattern = r'baa+'  # matches "ba" followed by one or more "a" (e.g. "baa", "baaa", "baaaa", ...)
pattern = r'oo*h'  # matches "o" followed by zero or more "o" and then "h" (e.g. "oh", "ooh", "oooh", ...)
pattern = r'colou?r'  # matches "color" and "colour"
pattern = r'beg.n'  # matches "begun", "begin", "begnn", ...

# Anchors (^, $)
pattern = r'^Hello'  # matches "Hello" at the beginning of the string
pattern = r'world!$'  # matches "world!" at the end of the string

# %% [markdown]
# ## 1. Hugging Face Datasets
#
# We will be using Hugging Face Datasets library ([https://huggingface.co/datasets](https://huggingface.co/datasets)). You can find the detailed documentation and tutorials here: [https://huggingface.co/docs/datasets/en/index](https://huggingface.co/docs/datasets/en/index)
#
# In this lab, we will load “tweet_eval” dataset and specifically the __emoji__ subset. For tokenization, we will only consider the text (contents of the tweet) but in this section we will also look at the labels. The description of the dataset is available in the dataset's card at [https://huggingface.co/datasets/cardiffnlp/tweet_eval](https://huggingface.co/datasets/cardiffnlp/tweet_eval)
#
# In order to load a dataset simply call load_dataset function specifying the dataset name. You can find many more datasets at the huggingface website.

# %%
dataset = datasets.load_dataset('tweet_eval', 'emoji')
print(dataset)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# The loaded dataset contains three subsets (“train”, “validation”, and “test”). Each consists of two columns: “text” and “label”. Label is an integer from 0 to 19 representing an emoji. See the dataset's card for more information. We can access the elements of the dataset like so:

# %%
for i in range(10):
    print(dataset['train'][i])
# Out:
# {'text': 'Sunday afternoon walking through Venice in the sun with @user ️ ️ ️ @ Abbot Kinney, Venice', 'label': 12}
# {'text': "Time for some BBQ and whiskey libations. Chomp, belch, chomp! (@ Lucille's Smokehouse Bar-B-Que)", 'label': 19}
# {'text': 'Love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ San…', 'label': 0}
# {'text': '️ ️ ️ ️ @ Toys"R"Us', 'label': 0}
# {'text': 'Man these are the funniest kids ever!! That face! #HappyBirthdayBubb @ FLIPnOUT Xtreme', 'label': 2}
# {'text': '#sandiego @ San Diego, California', 'label': 11}
# {'text': 'My little ️ ️ ️ ️ ️ #ObsessedWithMyDog @ Cafe Solstice Capitol Hill', 'label': 0}
# {'text': 'More #tinyepic things #tinyepicwestern, this one is crazy @user I may be one of your…', 'label': 19}
# {'text': 'Last night ️ @ Omnia Night Club At Caesars Palace', 'label': 0}
# {'text': 'friendship at its finest. ....#pixar #toystory #buzz #woody #friends #friendship #bff…', 'label': 7}

# %% [markdown]
# You can easily cast the dataset to the pandas DataFrame.

# %%
tweet_train_df = pd.DataFrame(dataset['train'])
print(tweet_train_df)
# Out:
#                                                     text  label
# 0      Sunday afternoon walking through Venice in the...     12
# 1      Time for some BBQ and whiskey libations. Chomp...     19
# 2      Love love love all these people ️ ️ ️ #friends...      0
# 3                                    ️ ️ ️ ️ @ Toys"R"Us      0
# 4      Man these are the funniest kids ever!! That fa...      2
# ...                                                  ...    ...
# 44995  Here to celebrate the Nunez wedding! Love my b...      0
# 44996  1 night in Paris.... Wait... @ Paris Las Vegas...      1
# 44997  Be safe this weekend everyone. #happylaborday ...     11
# 44998          Pizza (@ Five50 - @user in Las Vegas, NV)      1
# 44999  my mini is perfect, no one deserves her @ Las ...     13
#
# [45000 rows x 2 columns]

# %% [markdown]
# Even though we will not use the labels in this lab, we can plot their distribution in the training subset.

# %% [markdown]
# ### Dataset's filter function
# We can filter the examples using ```filter()``` method. See this link for more details https://huggingface.co/docs/datasets/en/use_dataset. Here is an example of filtering the short tweets (less than 20 characters) from the ```train``` subset.

# %%
short_tweets = dataset['train'].filter(lambda example: len(example['text']) < 20)
print(short_tweets)
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 506
# })

# %%
for i in range(10):
    print(short_tweets[i])
# Out:
# {'text': '️ ️ ️ ️ @ Toys"R"Us', 'label': 0}
# {'text': '️ @ Columbia River', 'label': 12}
# {'text': 'My weekend: @user 3', 'label': 6}
# {'text': 'good day today', 'label': 3}
# {'text': 'My last RT...', 'label': 2}
# {'text': '@ On Lake Cowichan', 'label': 13}
# {'text': '@ Macroplaza', 'label': 4}
# {'text': '@ BART Train', 'label': 6}
# {'text': '️ 4 a tbh&amp; rate', 'label': 0}
# {'text': '@user Oh nice!!', 'label': 14}

# %% [markdown]
# ### Dataset's map function
# Datasets library contains a very useful method map. It expects a function that will receive an example from the dataset. This function will be applied to all entries. We will calculate the length of the text (in characters) in each example.

# %%
def calculate_text_length(example):
    example['text_length'] = len(example['text'])
    return example

# %%
dataset = dataset.map(calculate_text_length, desc="Calculating text length")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# We can plot the histogram of the text lengths.

# %%
pd.DataFrame(dataset['train'])['text_length'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
avg_length = np.mean(dataset['train']['text_length'])
print(avg_length)
# Out:
# 71.01691111111111

# %% [markdown]
# <a name='e1'></a>
#
# ### Exercise 1: Questions about the datasets
# 1. (1p) What is the size of the training, test and validation datasets?
# 2. (1p) What is the average length (in characters) of the tweets in the training dataset?
# 3. (1p) Compare the distributions of tweet lengths between training, validation, and test subsets.

# %% [markdown]
# #### Answers
# 1. The training dataset has 45,000 entries while the test have 50,000 entries and validation 5,000 entries.
# 2. The average length of the tweets in the training dataset is: 71.01691111111111
# 3. ...

# %%
pd.DataFrame(dataset['train'])['text_length'].plot.hist(bins=50, label ='Train', color = 'blue')
pd.DataFrame(dataset['test'])['text_length'].plot.hist(bins=50 ,label ='Test', color = 'lightblue')
pd.DataFrame(dataset['validation'])['text_length'].plot.hist(bins=50, label ='Validation', color = 'lime')

plt.legend()
plt.xlabel('Tweet Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 2. Tokenization
#
# In this section we will preprocess the dataset by cleaning and tokenizing the entries.
# Datasets library contains a very useful method map. It expects a function that will receive an example from the dataset. This function will be applied to all entries.

# %% [markdown]
# ### 2.1 Cleaning the text

# %% [markdown]
# <a name='e2'></a>
#
# ### Exercise 2: Write the text cleaning function
#
# (6p) Include at least the following steps:
# 1. remove comma between numbers, i.e. 15,000 -> 15000,
# 2. remove multiple spaces,
# 3. space out the punctuation (i.e. "hello, world." -> "hello , world ."),
# 4. three more cleaning steps of your choice.

# %%
def clean(text):
    """
    Cleans the text
    Args:
        text: a string that will be cleaned

    Returns: the cleaned text
    """
    if text == '':
        return text

    text = text.lower()

    # remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # remove handles (@user)
    text = re.sub(r'@\S+', '', text)

    # remove @ symbols
    text = re.sub(r'[@#]', '', text)

    # remove invisible Unicode selectors 
    text = re.sub(r'[\u200d\uFE0F]', '', text)

    # remove comma between numbers
    text = re.sub(r'(\d+),(\d+)', r'\1\2', text)

    # space out punctuation
    text = re.sub(r'\s*([.,!?;:\"()])\s*', r' \1 ', text)

    # remove multiple spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %% [markdown]
# Let's test your cleaning function

# %%
for i in range(5):
    original = dataset['train'][i]['text']
    cleaned = clean(original)
    print('original:', original)
    print('cleaned:', cleaned)
    print()
# Out:
# original: Sunday afternoon walking through Venice in the sun with @user ️ ️ ️ @ Abbot Kinney, Venice
# cleaned: sunday afternoon walking through venice in the sun with abbot kinney , venice
#
# original: Time for some BBQ and whiskey libations. Chomp, belch, chomp! (@ Lucille's Smokehouse Bar-B-Que)
# cleaned: time for some bbq and whiskey libations . chomp , belch , chomp ! ( lucille's smokehouse bar-b-que )
#
# original: Love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ San…
# cleaned: love love love all these people friends bff celebrate blessed sundayfunday san…
#
# original: ️ ️ ️ ️ @ Toys"R"Us
# cleaned: toys " r " us
#
# original: Man these are the funniest kids ever!! That face! #HappyBirthdayBubb @ FLIPnOUT Xtreme
# cleaned: man these are the funniest kids ever ! ! that face ! happybirthdaybubb flipnout xtreme

# %% [markdown]
# Let's finally use the ```map()``` method and apply your `clean()` function to all entries of the dataset. We are overriding the `text` field with the cleaned version.

# %%
def clean_example(example):
    """
    Cleans the example from the Dataset. Uses clean() function for cleaning.
    Args:
        example: an example from the Dataset

    Returns: update example containing 'clean' column

    """
    text = example['text']
    clean_text = clean(text)

    # Update the example with the cleaned text
    example['text'] = clean_text.strip()
    return example


dataset = dataset.map(clean_example, desc="Cleaning text")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# ### 2.2 Build vocabulary
#
# In the previous section, we implemented the cleaning of the dataset. Now, we will tokenize the text splitting it by spaces. We will build a vocabulary based on the cleaned text of the `train` split. We will investigate some properties of corpora (e.g. Zipf's law).
#
# The function below builds a vocabulary from the dataset. It counts the occurrences of the words in the dataset using the Counter class. Check the documentation here [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter).

# %% [markdown]
# <a name='e3'></a>
# ### Exercise 3: Build the vocabulary
# (4p) Fill in the function below to build the vocabulary from the dataset. The function should return a `Counter` object with the words and their frequencies. The variable named `vocab` is already initialized as an empty `Counter` object.

# %%
def build_vocab_counter(dataset):
    """
    Builds a vocabulary from the dataset
    Args:
        dataset: a dataset

    Returns: a vocabulary

    """
    vocab = Counter()
    for text in dataset:
        text_content = text['text']
        cleaned_text = clean(text_content)
        vocab.update(cleaned_text.split())
    return vocab

# %%
vocab_counter = build_vocab_counter(dataset['train'])
print('Size of the vocabulary:', len(vocab_counter))
# Out:
# Size of the vocabulary: 61440

# %% [markdown]
# Because we created a counter, we can easily check the most and least common words in the vocabulary. Do the most common words make sense? How about the least common ones?

# %%
print('Most common:')
print(vocab_counter.most_common(10))
print('Least common:')
print(vocab_counter.most_common()[-10:])
# Out:
# Most common:
# [('.', 23628), ('!', 16956), ('the', 13455), (',', 12385), ('to', 7659), ('my', 7524), ('a', 6828), ('i', 6724), ('in', 5935), ('and', 5600)]
# Least common:
# [('corban…', 1), ('southbayla', 1), ('thedabberchick', 1), ('nector', 1), ('chefking1921express', 1), ('rolltide', 1), ('bffweekend', 1), ('nunez', 1), ('happylaborday', 1), ('five50', 1)]

# %% [markdown]
# We can also plot the counts of the words. You can check the [Power law](https://en.wikipedia.org/wiki/Power_law) if you are more interested.

# %%
plt.loglog([val for word, val in vocab_counter.most_common()])
plt.xlabel('rank')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# The plot shows that the distribution of the words in the vocabulary follows the Zipf's law. The most frequent word occurs approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc.
#
# We can also filter the vocabulary by the frequency of the words. We will only consider the most frequent words and mark the rest as the `<unk>` token. Here we set the maximum vocabulary size to 50,000. But you can experiment with different sizes.

# %%
# prune vocabulary
max_vocab_size = 50000
vocab = vocab_counter.most_common(max_vocab_size)
# cast to list of words
vocab = [word for word, _ in vocab]
print(len(vocab))
# Out:
# 50000

# %% [markdown]
# <a name='e4'></a>
# ### Exercise 4: Frequency of pairs of words
# Calculate the frequency of (neighbouring) pairs of words in the training dataset.
# 1. (2p) List the most and least common pairs. Do the most common pairs make sense?
# 2. (2p) How many pairs occur only once in the dataset?
# 3. (2p) Plot the distribution of the pair frequencies.

# %%
# most and least common pairs
pair_counter = Counter()
for example in dataset['train']:
    tokens = example['text'].split()
    if len(tokens) > 1:
        pair = zip(tokens, tokens[1:])
        pair_counter.update(pair)
print('Most common pairs:')
print(pair_counter.most_common(10))

print('\nLeast common pairs:')
# take the last 10 of most common = 10 least common
print(pair_counter.most_common()[-10:])

# pairs that occur only once
single_occurrence_count = sum(1 for count in pair_counter.values() if count == 1)
print(f'\nNumber of pairs occurring only once: {single_occurrence_count}')

# distribution of the pair frequencies
counts = [count for _, count in pair_counter.most_common()]
plt.loglog(counts)
plt.xlabel("Rank")
plt.ylabel("Frequency")
# Out:
# Most common pairs:
# [(('.', '.'), 7725), (('!', '!'), 4948), ((',', 'california'), 3340), (('&amp', ';'), 2019), (('los', 'angeles'), 1722), (('with', 'my'), 1072), (('in', 'the'), 1002), (('angeles', ','), 998), (('las', 'vegas'), 987), ((',', 'ca'), 916)]
#
# Least common pairs:
# [(('.', 'happylaborday'), 1), (('happylaborday', 'beer'), 1), (('beer', 'nv'), 1), (('pizza', '('), 1), (('(', 'five50'), 1), (('five50', '-'), 1), (('mini', 'is'), 1), (('one', 'deserves'), 1), (('deserves', 'her'), 1), (('her', 'las'), 1)]
#
# Number of pairs occurring only once: 198817
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# --- YOUR ANSWERS HERE

# %% [markdown]
# We will define and add three special tokens to our vocabulary:
# - unknown token ```<unk>```, which will represent words outside our vocabulary;
# - begining of sequence token ```<s>```, which will always be the first token of a sequence;
# - end of sequence token ```</s>```, which will mark the end of the sequence and allow the model to finish generation.

# %%
unknown_token = '<unk>'
bos_token = '<s>'
eos_token = '</s>'
vocab.append(unknown_token)
vocab.append(bos_token)
vocab.append(eos_token)

# %% [markdown]
# ### 2.3 Tokenize the dataset
# The function below tokenizes the cleaned text (```example['clean']```) by splitting it on spaces. It replaces the words that are not in the vocabulary with the `<unk>` token.

# %% [markdown]
# <a name='e5'></a>
# ### Exercise 5: Tokenize the dataset
# (4p) Fill in the function below to tokenize the dataset. The function will be applied to the dataset through the `map()` method, so it returns the updated example. Your task is to split the text by spaces and replace the words that are not in the vocabulary with the `<unk>` token. The tokenized sequence should start with the `bos_token` token and end with the `eos_token`.

# %%
def tokenize(text, vocab, unknown_token='<unk>', bos_token='<s>', eos_token='</s>'):
    """
    Tokenizes the text that is assumed to be cleaned first with the clean() function. The tokenized sequence should start with the `bos_token` token and end with the 'eos_token'.
    Args:
        text: a cleaned text
        vocab: a vocabulary as a list of words
        unknown_token: a token to replace the words that are not in the vocabulary
    Returns: tokenized text as a list of tokens

    """
    # Convert vocab list to a set for O(1) lookups
    vocab_set = set(vocab) if isinstance(vocab, list) else vocab

    # beginning of sequence token
    tokens = [bos_token]

    for word in text.split():
        if word in vocab_set:
            tokens.append(word)
        else:
            tokens.append(unknown_token)

    # end of sequence token
    tokens.append(eos_token)

    return tokens

# %% [markdown]
# Let's test the function:

# %%
tokenized = tokenize("what are you doing someunknowntoken ?", vocab, unknown_token, bos_token, eos_token)
print(tokenized)

assert tokenized[0] == bos_token, "First token should be bos_token"
assert tokenized[-1] == eos_token, "Last token should be eos_token"
# Out:
# ['<s>', 'what', 'are', 'you', 'doing', '<unk>', '?', '</s>']

# %%
def tokenize_example(example, vocab, unknown_token='<unk>', bos_token='<s>', eos_token='</s>'):
    """
    Applies the tokenize() function to the example from the Dataset
    Args:
        example: an example from the Dataset
        vocab: a vocabulary as a list of words
        unknown_token: a token to replace the words that are not in the vocabulary
    Returns: update example containing 'tokens' column

    """
    text = example['text']
    tokens = tokenize(text, vocab, unknown_token, bos_token, eos_token)
    example['tokens'] = tokens
    return example


dataset = dataset.map(tokenize_example,
                      fn_kwargs={
                          'vocab': vocab,
                          'unknown_token': unknown_token,
                          'bos_token': bos_token,
                          'eos_token': eos_token,
                      }, desc="Tokenizing text")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# Let us examine several entries from the dataset. We can see that the `tokens` column has been added to each example.

# %%
for i in range(5):
    print('Original tweet:')
    print(dataset['train'][i]['text'])
    print('Tokenized tweet:')
    print(dataset['train'][i]['tokens'])
# Out:
# Original tweet:
# sunday afternoon walking through venice in the sun with abbot kinney , venice
# Tokenized tweet:
# ['<s>', 'sunday', 'afternoon', 'walking', 'through', 'venice', 'in', 'the', 'sun', 'with', 'abbot', 'kinney', ',', 'venice', '</s>']
# Original tweet:
# time for some bbq and whiskey libations . chomp , belch , chomp ! ( lucille's smokehouse bar-b-que )
# Tokenized tweet:
# ['<s>', 'time', 'for', 'some', 'bbq', 'and', 'whiskey', 'libations', '.', 'chomp', ',', 'belch', ',', 'chomp', '!', '(', "lucille's", 'smokehouse', 'bar-b-que', ')', '</s>']
# Original tweet:
# love love love all these people friends bff celebrate blessed sundayfunday san…
# Tokenized tweet:
# ['<s>', 'love', 'love', 'love', 'all', 'these', 'people', 'friends', 'bff', 'celebrate', 'blessed', 'sundayfunday', 'san…', '</s>']
# Original tweet:
# toys " r " us
# Tokenized tweet:
# ['<s>', 'toys', '"', 'r', '"', 'us', '</s>']
# Original tweet:
# man these are the funniest kids ever ! ! that face ! happybirthdaybubb flipnout xtreme
# Tokenized tweet:
# ['<s>', 'man', 'these', 'are', 'the', 'funniest', 'kids', 'ever', '!', '!', 'that', 'face', '!', 'happybirthdaybubb', 'flipnout', 'xtreme', '</s>']

# %% [markdown]
# Make sure that the tokenization works as you intended. If not, revisit the cleaning and tokenization functions.

# %% [markdown]
# <a name='e6'></a>
# ### Exercise 6: Questions about the tokenization
# 1. (1p) How many unknown tokens are in the validation dataset after tokenization?
# 2. (1p) What is the distribution of the number of tokens in the training dataset?
# 3. (1p) How the number of tokens corresponds to the number of characters in our dataset?
# 4. (1p) How the size of the vocabulary (```max_vocab_size```) affects the number of unknown tokens?
# 5. (1p) How does the size of the vocabulary affect the number of tokens in the dataset?
# 6. (1p) Think about the advantages and disadvantages of the tokenization method we used. What are the cases when it will not work well?
# 7. (1p) Decide what vocabulary size you will use for the rest of the lab. It shouldn't be smaller than 10,000. Give a short explanation.

# %%
val_tokens_list = dataset['validation']['tokens']

# occurrences of <unk>
unk_count_val = sum(tokens.count(unknown_token) for tokens in val_tokens_list)

# number of tokens in validation to get the percentage
total_tokens_val = sum(len(tokens) for tokens in val_tokens_list)

print(f"1) Number of unknown tokens in validation: {unk_count_val}")
print(f"   Percentage of unknown tokens: {unk_count_val / total_tokens_val:.2%}")

train_tokens_list = dataset['train']['tokens']

token_lengths = [len(tokens) for tokens in train_tokens_list]
avg_tokens = np.mean(token_lengths)

plt.hist(token_lengths, bins=50, color='skyblue', edgecolor='black')
plt.axvline(avg_tokens, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {avg_tokens:.2f}')
plt.xlabel("Number of Tokens")
plt.ylabel("Frequency")
plt.legend()
print(f"2) Average number of tokens per tweet: {avg_tokens:.2f}")
plt.show()

total_chars_train = sum(len(example['text']) for example in dataset['train'])
total_tokens_train = sum(token_lengths)

ratio = total_chars_train / total_tokens_train

print(f"3) Total Tokens (Train): {total_tokens_train}")
print(f"   Total Characters (Train): {total_chars_train}")
print(f"   Average Characters per Token: {ratio:.2f}")

# 4) and 5) effect of max_vocab_size
vocab_sizes = [10000, 20000, 30000, 50000]
val_texts = dataset['validation']['text']

analysis_rows = []
for size in vocab_sizes:
    vocab_k = {word for word, _ in vocab_counter.most_common(size)}
    unk_k = 0
    total_k = 0

    for text in val_texts:
        words = text.split()
        unk_k += sum(1 for w in words if w not in vocab_k)
        total_k += len(words) + 2  # +2 for <s> and </s>

    analysis_rows.append((size, unk_k, total_k))

unk_counts = [row[1] for row in analysis_rows]
total_counts = [row[2] for row in analysis_rows]
unk_rates = [100 * u / t for u, t in zip(unk_counts, total_counts)]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# unknown-token behavior vs vocabulary size
axes[0].plot(vocab_sizes, unk_rates, marker='o', color='tab:red', linewidth=2)
axes[0].set_title("Q4: <unk> Rate vs max_vocab_size")
axes[0].set_xlabel("max_vocab_size")
axes[0].set_ylabel("<unk> rate (%)")
axes[0].grid(True, alpha=0.3)

# total-token behavior vs vocabulary size
axes[1].plot(vocab_sizes, total_counts, marker='o', color='tab:blue', linewidth=2)
axes[1].set_title("Q5: Total Tokens vs max_vocab_size")
axes[1].set_xlabel("max_vocab_size")
axes[1].set_ylabel("total tokens")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 1) Number of unknown tokens in validation: 5812
#    Percentage of unknown tokens: 8.47%
# 2) Average number of tokens per tweet: 14.26
# 3) Total Tokens (Train): 641544
#    Total Characters (Train): 3057321
#    Average Characters per Token: 4.77

# %% [markdown]
# --- YOUR ANSWERS HERE
#
# 1. In the validation set, there are 5812 unknown tokens, which is 8.47% of all validation tokens.
# 2. The token-count distribution in the training set is approximately unimodal and centered around the mean (14.26 tokens/tweet), with a right tail for longer tweets.
# 3. The train split has 641,544 total tokens and 3,057,321 total characters, so the average is 4.77 characters per token (roughly 5 chars/token).
# 4. See the left graph: as `max_vocab_size` increases, the `<unk>` rate decreases.
# 5. See the right graph: the total number of tokens remains effectively constant across vocabulary sizes for this tokenizer.
# 6. Advantages: simple, fast, interpretable, easy to debug. Disadvantages: weak handling of misspellings, slang, hashtags, morphology, and unseen words; this is especially problematic for social-media text.
# 7. We will use 50,000 vocabulary size for the rest of the lab, since it keeps `<unk>` relatively low while remaining computationally manageable.

# %% [markdown]
# ## 3. N-grams

# %% [markdown]
# <a name='e7'></a>
# ### Exercise 7: Counting unigrams
#
# (4p) Fill in the function below. Iterate through the dataset and count the tokens (unigrams). Check the documentation of the `Counter` dictionary (https://docs.python.org/3/library/collections.html#collections.Counter).

# %%
def calculate_unigrams(dataset):
    """
        Iterates through a dataset to count the frequency of individual tokens (unigrams).

        Args:
            dataset: a dataset where each example is a dictionary containing a 'tokens' key with
                a list of strings.

        Returns: a counter object mapping each unique token to its total number of occurrences across the entire dataset.
    """
    unigrams_counter = Counter()
    for example in tqdm.tqdm(dataset):
      #update counter with tokens from each tweet
      unigrams_counter.update(example['tokens'])
    return unigrams_counter

# %%
unigrams = calculate_unigrams(dataset['train'])
print(unigrams.most_common(10))
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 38095.85it/s]
# [('<s>', 45000), ('</s>', 45000), ('.', 23628), ('!', 16956), ('the', 13455), (',', 12385), ('<unk>', 11440), ('to', 7659), ('my', 7524), ('a', 6828)]

# %% [markdown]
# <a name='e8'></a>
# ### Exercise 8: Counting n-grams (with n > 1)
# (4p) Fill in the following function. It should iterate through the dataset and count the n-grams of the order `n` (a parameter).

# %%
def calculate_ngrams(dataset, n):
    """
    Iterates through the dataset to count the occurrences of n-gram contexts.

    Args:
        dataset: a dataset object where each example contains a 'tokens' key (a list of strings).
        n: the order of the n-gram model.

    Returns: a counter object mapping n-gram tuples to their frequency in the dataset.
    """
    ngrams_counter = Counter()
    for example in tqdm.tqdm(dataset):
        ### YOUR CODE HERE
        tokens = example['tokens']
        #create a window of size n to get touples for each pair of tokens
        example_ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
        ngrams_counter.update(example_ngrams)



        ### YOUR CODE ENDS HERE
    return ngrams_counter

# %%
bigrams = calculate_ngrams(dataset['train'], n=2)
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 34345.19it/s]

# %% [markdown]
# <a name='e9'></a>
# ### Exercise 9: Examining n-grams
# Count the higher-rank n-grams.
# 1. (1p) Check the most common n-grams of each rank.
# 2. (3p) Plot the number of n-grams dependent on the rank n.

# %%
n_values = [1, 2, 3, 4]
all_counts = {}

print("Calculating n-gram distributions...")

for n in n_values:
    # Calculate n-grams for the current rank
    counts = calculate_ngrams(dataset['train'], n)
    all_counts[n] = counts

    # Check the most common n-grams of each rank
    print(f"\n--- Top 10 Most Common {n}-grams ---")
    for gram, count in counts.most_common(10):
        print(f"{' '.join(gram)}: {count}")
# Out:
# Calculating n-gram distributions...
# 100%|██████████| 45000/45000 [00:01<00:00, 35683.48it/s]
# --- Top 10 Most Common 1-grams ---
# <s>: 45000
# </s>: 45000
# .: 23628
# !: 16956
# the: 13455
# ,: 12385
# <unk>: 11440
# to: 7659
# my: 7524
# a: 6828
# 100%|██████████| 45000/45000 [00:01<00:00, 34422.28it/s]
# --- Top 10 Most Common 2-grams ---
# . .: 7725
# ! !: 4948
# california </s>: 3383
# , california: 3340
# … </s>: 3143
# <unk> <unk>: 2201
# <unk> </s>: 2080
# &amp ;: 2019
# <s> i: 1952
# los angeles: 1722
# 100%|██████████| 45000/45000 [00:01<00:00, 34920.83it/s]
# --- Top 10 Most Common 3-grams ---
# . . .: 4123
# , california </s>: 3296
# ! ! !: 1981
# los angeles ,: 994
# angeles , california: 797
# ca ) </s>: 680
# , ca ): 677
# , … </s>: 635
# <unk> <unk> <unk>: 589
# <unk> <unk> </s>: 582
# 100%|██████████| 45000/45000 [00:01<00:00, 34368.36it/s]
# --- Top 10 Most Common 4-grams ---
# . . . .: 1186
# los angeles , california: 797
# angeles , california </s>: 792
# , ca ) </s>: 677
# ! ! ! !: 550
# beach , california </s>: 309
# <unk> <unk> <unk> </s>: 214
# san francisco , california: 202
# francisco , california </s>: 200
# san diego , california: 189

# %%
# Get the count of unique n-grams for each rank
unique_ngram_counts = [len(all_counts[n]) for n in n_values]

plt.figure(figsize=(10, 6))
plt.plot(n_values, unique_ngram_counts, marker='o', linestyle='-', color='teal', linewidth=2)

plt.title('Growth of Unique N-grams by Rank (n)', fontsize=14)
plt.xlabel('N-gram Rank (n)', fontsize=12)
plt.ylabel('Number of Unique N-grams', fontsize=12)
plt.xticks(n_values)
plt.grid(True, linestyle='--', alpha=0.6)

# Adding data labels on the points for clarity
for i, count in enumerate(unique_ngram_counts):
    plt.text(n_values[i], count, f' {count:,}', va='bottom', ha='center', fontweight='bold')

plt.show()

# %% [markdown]
# Having n-grams as Counters is nice, but for generation and calculating perplexity (coming up next) this would be inefficient. For this reason, we will create a class representing language models that are based on n-grams. You can check a quick guide on Object Oriented Programming (OOP) in Python here https://www.geeksforgeeks.org/python/python-oops-concepts/
#
# Currently, we have the counts of n-grams. The main problem is that, for generation, we need the counts of each token in the vocabulary GIVEN the previous (n-1) tokens. If we were to leave the n-gram Counter as is, we would have to iterate over each entry and check if the first (n-1) tokens matches what we have already generated. To mitigate this issue, we will create a dictionary of Counters, where keys will be the tuples with (n-1) n-grams. This allows us to simply retrieve the appropriate counter.
#
# We are also start using numpy, which is a very potent and prolific library for matrices and their manipulations. It is highly optimized, so it will make our code run faster. You can check the documentation here https://numpy.org/doc/stable/

# %% [markdown]
# <a name='e10'></a>
# ### Exercise 10: N-gram Language Model class
# Fill in the two methods in NgramLanguageModel class:
#  1. (3p) `build_model()` builds the model, which is a `dictionary` of `Counters`. The keys of this dictionary are the tokens of the n-grams without the last token. The values of the dictionary are separate `Counters` of the final tokens. For example, in case of the tri-grams `("at", "the","university")` with count 3 and `("at", "the","party")` with count 2, the previous tokens for both is a bi-gram `("at", "the")`. The resulting `Counter` for this bi-gram is `{"university": 3, "party": 2}`.
#  2. (3p) `get_counts()` returns a numpy array with counts of all vocab tokens given the passed previous tokens. This function operates on the indices of tokens in the vocabulary. The fastest way to get the index of a token is to use the `self.word_to_index` dictionary. It will return the index of the token: `self.word_to_index[token]`.

# %%
class NgramLanguageModel:
    """
    A dictionary-based N-gram Language Model.

    Attributes:
        vocab: a list of unique tokens in the language.
        word_to_index: the apping from token strings to their integer indices.
        vocab_size: total number of unique tokens in the vocabulary.
        ngrams: a counter of n-gram tuples.
        n: the order of the n-gram model
        model (dict): a nested dictionary where keys are context tuples and values are Counters of following tokens.
    """
    def __init__(self, ngrams, n, vocab):
        self.vocab = vocab
        self.word_to_index = {word: i for i, word in enumerate(self.vocab)}
        self.vocab_size = len(vocab)
        self.ngrams = ngrams
        self.n = n
        self.model = self.build_model()

    def build_model(self):
        """
        Converts flat n-gram counts into a nested dictionary structure for efficiency.

        Returns:a dictionary where: key: tuple (the context of length n-1), value: collections.Counter (counts of tokens following that context)
        """
        model = {}
        for ngram, count in tqdm.tqdm(self.ngrams.items()):
            context = ngram[:-1]  # get all tokens except the last
            target = ngram[-1]   # last token is the target

            if context not in model:
                model[context] = Counter()
            model[context][target] += count
        return model

    def get_counts(self, previous_tokens):
        """
        Retrieves the counts of all vocabulary tokens that follow a given context. Only the last (n-1) tokens are used as the context.

        Args:
            previous_tokens: the sequence of tokens seen so far.

        Returns: an integer np.ndarray of shape (vocab_size,) where the value at index 'i' is the count of vocab[i] following the context.
        """
        if self.n == 1:
            previous_tokens = ()
        else:
            previous_tokens = tuple(previous_tokens[-(self.n - 1):])
        counts = np.zeros(self.vocab_size, dtype=int)
        ### YOUR CODE ENDS HERE
        if previous_tokens in self.model:
            for word, count in self.model[previous_tokens].items():
                if word in self.word_to_index:
                    idx = self.word_to_index[word]
                    counts[idx] = count


        ### YOUR CODE ENDS HERE
        return counts

# %% [markdown]
# Let us test this class on a toy example

# %%
toy_trigrams = Counter({
    ("at", "the", "university"): 3,
    ("at", "the", "party"): 2,
    ("feed", "the", "cat"): 1,
    ("feed", "the", "dog"): 4,
})

toy_vocab = ["at", "the", "university", "party", "feed", "cat", "dog"]

toy_lm = NgramLanguageModel(toy_trigrams, 3, toy_vocab)
print('model', toy_lm.model)

counts = toy_lm.get_counts(("at", "the"))
print('counts', counts)

assert type(counts) == np.ndarray, "counts should be a numpy array"
assert counts.size == len(toy_vocab)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 97541.95it/s]
# model {('at', 'the'): Counter({'university': 3, 'party': 2}), ('feed', 'the'): Counter({'dog': 4, 'cat': 1})}
# counts [0 0 3 2 0 0 0]

# %% [markdown]
# The `toy_lm.model` should be something like this:
#
# ```
# {
#     ('at', 'the'): Counter({
#         'university': 3,
#         'party': 2
#     }),
#     ('feed', 'the'): Counter({
#         'dog': 4,
#         'cat': 1
#     })
# }
# ```
#
# The `counts` should be:
# ```
# [0 0 3 2 0 0 0]
# ```

# %% [markdown]
# Now, we can create our bi-gram language model

# %%
bigram_lm = NgramLanguageModel(bigrams, 2, vocab)
# Out:
# 100%|██████████| 247981/247981 [00:00<00:00, 1560097.59it/s]

# %% [markdown]
# <a name='e11'></a>
# ### Exercise 11: Greedy Generate
# (4p) Implement the following greedy generation function. It should first call the model object (passed as a parameter) to obtain the counts of each token in our vocabulary given the already generated sequence. Next, it should select the token with the highest count and append it to the already generated sequence. You might find `numpy.argmax()` function handy (https://numpy.org/doc/stable/reference/generated/numpy.argmax.html).

# %%
def greedy_generate(languge_model, max_tokens, bos_token, eos_token, previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else list(previous_tokens)
    if len(generated) == 0:
        generated = [bos_token]
    while generated[-1] != eos_token and len(generated) < max_tokens:
        counts = languge_model.get_counts(generated)
        if np.sum(counts) == 0:
            generated.append(eos_token)
            break
        next_token_idx = np.argmax(counts)
        next_token = languge_model.vocab[next_token_idx]
        generated.append(next_token)
    return generated

# %% [markdown]
# Let's test the generations starting with the empty sequence and with "you can...".

# %%
generated = greedy_generate(bigram_lm, 15, bos_token, eos_token)
print(generated)

generated = greedy_generate(bigram_lm, 15, bos_token, eos_token, previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
# ['<s>', 'you', 'can', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']

# %% [markdown]
# <a name='e12'></a>
# ### Exercise 12: Sampling Generate
# (4p) Implement the sampling generation function. It is similar to the previous one, but the selection of the next tokens should be random, with the probabilities based on the counts returned by the model. Make sure you take care of the case where the n-gram was not encountered (meaning that the model will return all counts equal to zero). Check `numpy.random` package for the appropriate function to sample the tokens with respect to their probabilities (https://numpy.org/doc/2.4/reference/random/legacy.html).

# %%
def sampling_generate(languge_model, max_tokens, bos_token, eos_token, previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else list(previous_tokens)
    if len(generated) == 0:
        generated = [bos_token]

    while generated[-1] != eos_token and len(generated) < max_tokens:
        # Get next-token counts for the current context.
        counts = languge_model.get_counts(generated)
        total = np.sum(counts)

        # If context is unseen, end the sequence.
        if total == 0:
            generated.append(eos_token)
            break

        # Convert counts to probabilities and sample one token index.
        prob = counts / total
        next_token_idx = np.random.choice(np.arange(languge_model.vocab_size), p=prob)
        generated.append(languge_model.vocab[next_token_idx])

    return generated

# %% [markdown]
# Let's test the function:

# %%
generated = sampling_generate(bigram_lm, 15, bos_token, eos_token)
print(generated)

generated = sampling_generate(bigram_lm, 15, bos_token, eos_token, previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', 'christmas', 'stockingstuffer', 'christmasdog', 'dogtoys…', '</s>']
# ['<s>', 'you', 'can', 'someone', "can't", 'believe', 'you', 'to', 'exercise', 'hangar', '18', '!', '!', 'come', 'in']

# %% [markdown]
# <a name='e13'></a>
# ### Exercise 13: Smoothing
#
# (4p) In this exercise you will add smoothing to the generation. Smoothing parameter $\alpha$ is controlled by the parameter `smoothing` with a default value of `1` (too high, as you will see in the next exercises). Consult the lecture slides for the formulation.

# %%
def sampling_generate_smoothing(language_model, max_tokens, bos_token, eos_token, smoothing=1,
                                previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else list(previous_tokens)
    if len(generated) == 0:
        generated = [bos_token]

    while generated[-1] != eos_token and len(generated) < max_tokens:
        counts = language_model.get_counts(generated)
        smoothed_counts = counts + smoothing
        total = np.sum(smoothed_counts)

        if total == 0:
            generated.append(eos_token)
            break

        probabilities = smoothed_counts / total
        next_token_idx = np.random.choice(np.arange(language_model.vocab_size), p=probabilities)
        generated.append(language_model.vocab[next_token_idx])

    return generated

# %%
generated = sampling_generate_smoothing(bigram_lm, 15, bos_token, eos_token, smoothing=1)
print(generated)

generated = sampling_generate_smoothing(bigram_lm, 15, bos_token, eos_token, smoothing=1,
                                        previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', 'veranda', 'anywhereispossible…', 'v', 'peete', 'griffith_observatory', 'sumnermeadowsdogpark', 'professionals', 'νξθ•βαιιεrϊηα', "can't…", 'richmond…', 'gentalman', 'pest', 'longbeach', 'bloomed']
# ['<s>', 'you', 'can', 'inventory', 'heeeeeeeerrreeeeeeeeee', 'springbreak2015', 'viewfromabove', 'nothingbutdenim', 'doom', 'began', 'baconandbutter…', 'suprememuffler', 'row3', 'texture', 'robshome']

# %% [markdown]
# <a name='e14'></a>
# ### Exercise 14: Qualitative Analysis of Generations
# 1. (2p) Examine the generations of the functions above (greedy, sampling and sampling with smoothing). Make sure to experiment with different values of smoothing. Generate at least 5 examples for each function and smoothing value.
# 2. (2p) Do the same as above but start with a sequence of tokens (for example `["<s>", "you", "can"]`) Try at least 3 starting sequences.

# %%
# random seed so it's better to reproduce
np.random.seed(42)

max_tokens = 15
num_examples = 5
smoothing_values = [1.0, 0.1, 0.01]
starting_sequences = [
    ["<s>", "you", "can"],
    ["<s>", "i", "love"],
    ["<s>", "he", "likes"],
]

def pretty_tokens(tokens) :
  # helper function to remove boundary tokens to make the output easier to read
  return " ".join([t for t in tokens if t not in {bos_token, eos_token}])
def print_examples(title, generate_fn, n_examples=5):
    # helper function: print several generations for one setting.
    print(f"\n{title}")
    for i in range(n_examples):
        tokens = generate_fn()
        print(f"{i + 1}. {tokens}")
        print(f"   text: {pretty_tokens(tokens)}")

print_examples(
    "Greedy without start sequence",
    lambda: greedy_generate(bigram_lm, max_tokens, bos_token, eos_token),
    num_examples,
)

print_examples(
    "Sampling without start sequence",
    lambda: sampling_generate(bigram_lm, max_tokens, bos_token, eos_token),
    num_examples,
)
for alpha in smoothing_values:
    print_examples(
        f"Sampling smoothing with alpha={alpha} and without start sequence ",
        lambda a=alpha: sampling_generate_smoothing(bigram_lm, max_tokens, bos_token, eos_token, smoothing=a),
        num_examples,
    )
for start in starting_sequences:
  print(f"\n{'=' * 80}")
  print(f"Starting sequence: {start}")

  print_examples(
      f"Greedy with start sequence {start}",
      lambda s=start: greedy_generate(bigram_lm, max_tokens, bos_token, eos_token, previous_tokens=list(s)),
      num_examples,
  )

  print_examples(
      f"Sampling with start sequence {start}",
      lambda s=start: sampling_generate(bigram_lm, max_tokens, bos_token, eos_token, previous_tokens=list(s)),
      num_examples,
  )

  for alpha in smoothing_values:
     print_examples(
        f"Sampling smoothing with alpha={alpha} and with start sequence {start}",
        lambda s=start, a=alpha: sampling_generate_smoothing(bigram_lm, max_tokens, bos_token, eos_token, smoothing=a, previous_tokens=list(s)),
        num_examples,
    )
# Out:
# Greedy without start sequence
# 1. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 2. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 3. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 4. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 5. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
#
# Sampling without start sequence
# 1. ['<s>', 'disneyland', '</s>']
#    text: disneyland
# 2. ['<s>', 'rest', 'of', 'my', 'little', 'time', 'coronado', 'island', '</s>']
#    text: rest of my little time coronado island
# 3. ['<s>', 'the', 'uscap2016', 'representing', 'my', 'life', '!', 'the', 'husband', 'on', 'my', 'son', '!', '!', '…']
#    text: the uscap2016 representing my life ! the husband on my son ! ! …
# 4. ['<s>', 'she', 'heard', 'of', 'school', '</s>']
#    text: she heard of school
# 5. ['<s>', 'my', 'front', 'of', 'the', 'gastropig', '</s>']
#    text: my front of the gastropig
#
# Sampling smoothing with alpha=1.0 and without start sequence
# 1. ['<s>', 'foodz', '58', 'poster', 'sicpic', 'lamill…', 'finger', 'hugecalves', 'note', 'hodads', 'shareyourears', 'sia__official', 'hairbyconnie', 'snooki', 'thatniggaleft']
#    text: foodz 58 poster sicpic lamill… finger hugecalves note hodads shareyourears sia__official hairbyconnie snooki thatniggaleft
# 2. ['<s>', 'thanks', 'jake_vujovich', 'mozzarella', 'integrate', 'coincidentally', 'familiapizano…', 'donebyyourstruly', 'jb', 'give…', 'raining', 'lwtsummit', 'lovemeharter…', 'episodevii', 'trestle']
#    text: thanks jake_vujovich mozzarella integrate coincidentally familiapizano… donebyyourstruly jb give… raining lwtsummit lovemeharter… episodevii trestle
# 3. ['<s>', 'riverside', 'battling', 'lmd', 'christopher', 'seattlefamily', 'beanie', 'mastering', 'myshit', 'hummingbird', 'sun', 'craterlakenationalpark', 'schwarzkopfusa…', 'gangrelated', 'cleanedthebitches']
#    text: riverside battling lmd christopher seattlefamily beanie mastering myshit hummingbird sun craterlakenationalpark schwarzkopfusa… gangrelated cleanedthebitches
# 4. ['<s>', 'love', 'asked…', 'instatravel…', 'fw16collection', "・・・lombard's", 'mexicans', 'involved', '71st', 'exited', 'crabhouse', 'dopemusicians', '31unanswered', 'animalsbzzselfiescavenger', 'loving…']
#    text: love asked… instatravel… fw16collection ・・・lombard's mexicans involved 71st exited crabhouse dopemusicians 31unanswered animalsbzzselfiescavenger loving…
# 5. ['<s>', 'christmastreefarm…', 'latenightdrinks', 'fairmonthotel…', 'supercars', 'angl', 'salmon…', 'lazysunday…', 'wrong', '10am', 'christmas2015', 'westcoastsoulsister', 'chaperoning', 'maileemusic', 'magick']
#    text: christmastreefarm… latenightdrinks fairmonthotel… supercars angl salmon… lazysunday… wrong 10am christmas2015 westcoastsoulsister chaperoning maileemusic magick
#
# Sampling smoothing with alpha=0.1 and without start sequence
# 1. ['<s>', "it's", 'polka', 'latingrammys2015', 'gypsies', 'enjoylife', 'abel', 'noooo', 'iphonecamera', 'anthropologie', '3rdfullalbum', 'sprays', 'reaper', 'sorority', 'dadgummit']
#    text: it's polka latingrammys2015 gypsies enjoylife abel noooo iphonecamera anthropologie 3rdfullalbum sprays reaper sorority dadgummit
# 2. ['<s>', 'street', 'veges', "muphy's", 'backtoschool', 'performed', 'gondola', 'gaypride', 'programmed', 'baestfriend', 'feeling', 'mr_rubekicking', 'i-405', 'dos', 'goth']
#    text: street veges muphy's backtoschool performed gondola gaypride programmed baestfriend feeling mr_rubekicking i-405 dos goth
# 3. ['<s>', 'some', 'gently', 'bbtm', 'hootersforheroes', 'stage5clinger', 'hipstamatic', 'fourtwenty', 'juicejuice', 'godiva', 'bowl…', 'goats', 'feelinghappy…', 'zone', 'topman']
#    text: some gently bbtm hootersforheroes stage5clinger hipstamatic fourtwenty juicejuice godiva bowl… goats feelinghappy… zone topman
# 4. ['<s>', 'excited', 'without', 'castaway', 'stoic', 'push-up', 'english', 'i&amp', 'marinegirlfriend', 'ayer', 'honors', 'xcelmusic…', 'herman', 'theyloveit', 'pawlak']
#    text: excited without castaway stoic push-up english i&amp marinegirlfriend ayer honors xcelmusic… herman theyloveit pawlak
# 5. ['<s>', 'yeah', 'pacificalphaphi…', '9-10pm', 'theforum', 'neighbours', 'krystalchang', 'sorority', 'lakes', 'dcmoments', 'tookamonth', 'both', 'salabhasana…', 'porteon', 'boxlife']
#    text: yeah pacificalphaphi… 9-10pm theforum neighbours krystalchang sorority lakes dcmoments tookamonth both salabhasana… porteon boxlife
#
# Sampling smoothing with alpha=0.01 and without start sequence
# 1. ['<s>', 'so', 'sexy', 'morningselfie', 'happybdaystink', 'brass', 'metallica', 'tj', 'cred…', 'opener', 'whitestonedesigngroup', 'akadventures', 'lulus', 'justro', 'caliweather']
#    text: so sexy morningselfie happybdaystink brass metallica tj cred… opener whitestonedesigngroup akadventures lulus justro caliweather
# 2. ['<s>', 'all', 'the', 'moods', 'deluxe…', 'applepicking…', 'tame', 'eiswelt', 'patschmidt', 'everydaycalifornia', 'exposureskate2015', 'artzool', 'theherberynw', 'reef', 'amazingly']
#    text: all the moods deluxe… applepicking… tame eiswelt patschmidt everydaycalifornia exposureskate2015 artzool theherberynw reef amazingly
# 3. ['<s>', 'owens', 'gage', 'bowl', 'next', 'iphone6s…', "i've", 'been', 'instafoodapp…', 'lushlife…', 'throwup', "sue's", 'eliminate', 'exploding', 'dogdaycare']
#    text: owens gage bowl next iphone6s… i've been instafoodapp… lushlife… throwup sue's eliminate exploding dogdaycare
# 4. ['<s>', 'holy', 'customblends', 'bfam…', 'theeinusa2016', 'seestra', "lil'", 'seeyousoon', 'grinding', 'beanie…', 'portrait_perfection', 'hulahooped', 'ivan', 'w//', '15403']
#    text: holy customblends bfam… theeinusa2016 seestra lil' seeyousoon grinding beanie… portrait_perfection hulahooped ivan w// 15403
# 5. ['<s>', 'pretty', 'hudsontheatres', 'wookiee', 'presented', 'stayinline', 'zef_alien', 'homie', 'squaaaaaa', 'powercouple', 'bowling…', 'lizards', 'thesecret…', 'losreyes', 'wow']
#    text: pretty hudsontheatres wookiee presented stayinline zef_alien homie squaaaaaa powercouple bowling… lizards thesecret… losreyes wow
#
# ================================================================================
# Starting sequence: ['<s>', 'you', 'can']
#
# Greedy with start sequence ['<s>', 'you', 'can']
# 1. ['<s>', 'you', 'can', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: you can you for the best friend . . . . . . .
# 2. ['<s>', 'you', 'can', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: you can you for the best friend . . . . . . .
# 3. ['<s>', 'you', 'can', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: you can you for the best friend . . . . . . .
# 4. ['<s>', 'you', 'can', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: you can you for the best friend . . . . . . .
# 5. ['<s>', 'you', 'can', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: you can you for the best friend . . . . . . .
#
# Sampling with start sequence ['<s>', 'you', 'can']
# 1. ['<s>', 'you', 'can', 'possibly', 'be', 'hellish', 'so', 'stunning', 'yesterday', 'with', 'ian', 'and', 'this', 'guy', 'symbiosisgathering']
#    text: you can possibly be hellish so stunning yesterday with ian and this guy symbiosisgathering
# 2. ['<s>', 'you', 'can', 'eat', 'as', 'a', 'y', '<unk>', 'is', 'as', 'usual', '-1', 'wrenchin', ',', 'california']
#    text: you can eat as a y <unk> is as usual -1 wrenchin , california
# 3. ['<s>', 'you', 'can', 'be', 'heard', 'r', 'd', 'atthebeach', 'santa', 'monica', 'pier', '</s>']
#    text: you can be heard r d atthebeach santa monica pier
# 4. ['<s>', 'you', 'can', 'give', 'us', 'mixing', 'in', 'san', 'francisco', 'bay', '.', 'it', 'when', 'you', 'guys']
#    text: you can give us mixing in san francisco bay . it when you guys
# 5. ['<s>', 'you', 'can', 'i', 'love', 'husband', 'is', 'my', 'ass', 'bullshit', '"', 'photoshoot', 'to', 'the', 'business']
#    text: you can i love husband is my ass bullshit " photoshoot to the business
#
# Sampling smoothing with alpha=1.0 and with start sequence ['<s>', 'you', 'can']
# 1. ['<s>', 'you', 'can', '9-10pm', 'howls', 'littlefoot', 'thedfm', 'vet…', 'lashextensions', 'weekendtrip', 'jem', 'garagelife', 'louis', 'men', 'jeeeeeeep']
#    text: you can 9-10pm howls littlefoot thedfm vet… lashextensions weekendtrip jem garagelife louis men jeeeeeeep
# 2. ['<s>', 'you', 'can', '4mybabies', 'weareccv…', 'happyfridaysncor', 'producers', 'gowns', '365photochallenge…', 'musicproducer…', 'selfiesandshit', 'pcfmodesto…', '~~', 'totems', 'jerstrong']
#    text: you can 4mybabies weareccv… happyfridaysncor producers gowns 365photochallenge… musicproducer… selfiesandshit pcfmodesto… ~~ totems jerstrong
# 3. ['<s>', 'you', 'can', 'mso', 'ministry', 'proudly-', 'libertine', 'plz', 'astounds', 'course', 'palmtrees', 'harder', 'positive', 'yacking', 'hob']
#    text: you can mso ministry proudly- libertine plz astounds course palmtrees harder positive yacking hob
# 4. ['<s>', 'you', 'can', 'lovecats', 'bixby', 'tioga', 'parktime…', 'wemadeit', 'high_noon_cult', 'dlabarba', 'hemlocckk', 'libertineoakland', 'bass', 'scarymovie', 'dspeedthebarber']
#    text: you can lovecats bixby tioga parktime… wemadeit high_noon_cult dlabarba hemlocckk libertineoakland bass scarymovie dspeedthebarber
# 5. ['<s>', 'you', 'can', 'imacharacter', 'psp', 'stocktonca', 'salted', 'beaverton', 'fitgirlsguide…', 'holy', 'aid', 'indianfoodftw', 'clarinets', 'muchodjs', 'margikentstudios']
#    text: you can imacharacter psp stocktonca salted beaverton fitgirlsguide… holy aid indianfoodftw clarinets muchodjs margikentstudios
#
# Sampling smoothing with alpha=0.1 and with start sequence ['<s>', 'you', 'can']
# 1. ['<s>', 'you', 'can', 'flyfamily…', 'shoppin', 'me-corey', 'cheetocat', 'handpressed', 'pugglelove', 'aviators', 'tons', 'easily', 'trail', 'salem', 'pravanavivids…']
#    text: you can flyfamily… shoppin me-corey cheetocat handpressed pugglelove aviators tons easily trail salem pravanavivids…
# 2. ['<s>', 'you', 'can', 'find', 'hoodoo', 'bae/', 'visiting', 'gameshakers…', "geoffrey's", 'bloom', 'عزم_لا_يهون', '5thstreetpublicmarket…', 'managerlife', 'dig…', 'reaper']
#    text: you can find hoodoo bae/ visiting gameshakers… geoffrey's bloom عزم_لا_يهون 5thstreetpublicmarket… managerlife dig… reaper
# 3. ['<s>', 'you', 'can', 'coral', 'smelling', 'sanchezink', 'kcls', 'isurfbecause', 'surferclaus', 'theformationworldtour', 'omens', "frank's", 'rounds30…', 'erickhercules', 'iphoneshot']
#    text: you can coral smelling sanchezink kcls isurfbecause surferclaus theformationworldtour omens frank's rounds30… erickhercules iphoneshot
# 4. ['<s>', 'you', 'can', 'afflicted', 'iwantchicken…', 'preserve', 'galleries1988', 'calabama…', 'lowman', 'abbey…', 'dek', "12'6", 'garden', 'gammysyams', 'athlete']
#    text: you can afflicted iwantchicken… preserve galleries1988 calabama… lowman abbey… dek 12'6 garden gammysyams athlete
# 5. ['<s>', 'you', 'can', 'havnt', 'lifeinamerica', 'naturecalls', 'episode…', 'beauteous', '*accidentally', 'bekind', 'synopsys', 'beiber', 'tinged', 'bringon2016', 'coldblooded']
#    text: you can havnt lifeinamerica naturecalls episode… beauteous *accidentally bekind synopsys beiber tinged bringon2016 coldblooded
#
# Sampling smoothing with alpha=0.01 and with start sequence ['<s>', 'you', 'can']
# 1. ['<s>', 'you', 'can', 'love', 'beach', ',', 'ca', ')', '</s>']
#    text: you can love beach , ca )
# 2. ['<s>', 'you', 'can', 'call', 'all', 'the', 'gram', 'grandmahoney', 'exact', 'getoutside', 'orkila', 'pantages', 'salad…', 'earlymothersdaypresent', 'champions']
#    text: you can call all the gram grandmahoney exact getoutside orkila pantages salad… earlymothersdaypresent champions
# 3. ['<s>', 'you', 'can', 'you', '<unk>', 'yum', 'carmela', 'tory', 'rockclimbing', '⠀⠀⠀⠀⠀⠀⠀working…', 'berrygolf', 'wanderlustfestival', 'turnt', 'loxs', 'sonatalife']
#    text: you can you <unk> yum carmela tory rockclimbing ⠀⠀⠀⠀⠀⠀⠀working… berrygolf wanderlustfestival turnt loxs sonatalife
# 4. ['<s>', 'you', 'can', 'strong', 'audra', 'holly', 'anya', 'went', 'nwanidesign', 'weekend…', 'cartier', 'memorial…', 'flowery', 'unforgetablenight', 'thelucasbros']
#    text: you can strong audra holly anya went nwanidesign weekend… cartier memorial… flowery unforgetablenight thelucasbros
# 5. ['<s>', 'you', 'can', 'artwork…', 'blaséontheoutsideblessedontheinside', 'dopeee', 'oakleythegoldenhiker', 'thisguy', 'skateboarding…', 'gotta', 'murked', 'rolling', 'ninversary', 'sleepcreep', 'mywild…']
#    text: you can artwork… blaséontheoutsideblessedontheinside dopeee oakleythegoldenhiker thisguy skateboarding… gotta murked rolling ninversary sleepcreep mywild…
#
# ================================================================================
# Starting sequence: ['<s>', 'i', 'love']
#
# Greedy with start sequence ['<s>', 'i', 'love']
# 1. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 2. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 3. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 4. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
# 5. ['<s>', 'i', 'love', 'you', 'for', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.']
#    text: i love you for the best friend . . . . . . .
#
# Sampling with start sequence ['<s>', 'i', 'love']
# 1. ['<s>', 'i', 'love', 'the', 'pleasure', 'barona', 'resort', 'casino', '</s>']
#    text: i love the pleasure barona resort casino
# 2. ['<s>', 'i', 'love', 'this', 'post', 'coffee', '</s>']
#    text: i love this post coffee
# 3. ['<s>', 'i', 'love', '!', '!', '<unk>', '</s>']
#    text: i love ! ! <unk>
# 4. ['<s>', 'i', 'love', 'this', 'trip', 'to', 'me', '?', '?', 'nevada', 'lake', '</s>']
#    text: i love this trip to me ? ? nevada lake
# 5. ['<s>', 'i', 'love', '<unk>', '<unk>', 'red…', '</s>']
#    text: i love <unk> <unk> red…
#
# Sampling smoothing with alpha=1.0 and with start sequence ['<s>', 'i', 'love']
# 1. ['<s>', 'i', 'love', 'chinesecuisine', 'feelslikespring', 'traveling…', 'cacacraig1', "naimie's", 'prom2k15', 'blu…', 'whoknew', 'tutoriais', 'mjthestylist_', 'chihiro', 'sanfran']
#    text: i love chinesecuisine feelslikespring traveling… cacacraig1 naimie's prom2k15 blu… whoknew tutoriais mjthestylist_ chihiro sanfran
# 2. ['<s>', 'i', 'love', 'this', 'blu-ray', 'bleachbit', 'pee_la', 'karl', 'hiddenpondtrail', 'gottagetouttahere…', 'rbi', 'deez', 'wosa_usa', 'bot', 'trishapaytas']
#    text: i love this blu-ray bleachbit pee_la karl hiddenpondtrail gottagetouttahere… rbi deez wosa_usa bot trishapaytas
# 3. ['<s>', 'i', 'love', 'bulgogi', 'shining', 'asha', 'toothpick', 'roast…', 'loveforall', 'goodlookingboy', 'theshopproscooterlab…', 'medusa', 'family-run…', 'officialamericasteam', 'ddo']
#    text: i love bulgogi shining asha toothpick roast… loveforall goodlookingboy theshopproscooterlab… medusa family-run… officialamericasteam ddo
# 4. ['<s>', 'i', 'love', 'tracy', 'mitesoro…', 'address', 'mendoza', '1948', 'beautyallaroundme', 'shogun', 'rob', 'francoli', 'craven', '$298', 'wiseguycuts']
#    text: i love tracy mitesoro… address mendoza 1948 beautyallaroundme shogun rob francoli craven $298 wiseguycuts
# 5. ['<s>', 'i', 'love', 'threemen', 'ingrid…', 'announcing', 'sdit', 'personalize', 'tricks', 'beach…', 'tshirtprinting…', 'bodybuilder', '6p', 'detail', 'volleyball']
#    text: i love threemen ingrid… announcing sdit personalize tricks beach… tshirtprinting… bodybuilder 6p detail volleyball
#
# Sampling smoothing with alpha=0.1 and with start sequence ['<s>', 'i', 'love']
# 1. ['<s>', 'i', 'love', '!', 'los', 'afterparty…', 'cs01', 'babyroyal', 'chrza', 'slayer', 'sigelei…', 'indyjammajones', 'infatuation…', 'yahemi', 'aamiin']
#    text: i love ! los afterparty… cs01 babyroyal chrza slayer sigelei… indyjammajones infatuation… yahemi aamiin
# 2. ['<s>', 'i', 'love', 'cardoftheday', 'diesel', 'ariesspears', 'voiceofhair', 'partyfavors', 'dooooo', 'roommatelife', 'merlin__b', "partyin'", 'blondehairdontcare', 'balling', 'core']
#    text: i love cardoftheday diesel ariesspears voiceofhair partyfavors dooooo roommatelife merlin__b partyin' blondehairdontcare balling core
# 3. ['<s>', 'i', 'love', 'you', 'so', 'long', 'frankie', 'dota', 'sky…', 'veggie…', 'workanniversary', 'acehotelpalmsprings…', 'vitamindday…', 'wizardingworldofharrypotter', 'familypictures']
#    text: i love you so long frankie dota sky… veggie… workanniversary acehotelpalmsprings… vitamindday… wizardingworldofharrypotter familypictures
# 4. ['<s>', 'i', 'love', 'to', 'be', 'deals', '12th', 'icon', 'aha', 'breakawayweekend15…', 'bestfriends…', 'deets', 'joytothehills', 'merryxmas…', 'winner']
#    text: i love to be deals 12th icon aha breakawayweekend15… bestfriends… deets joytothehills merryxmas… winner
# 5. ['<s>', 'i', 'love', 'thanksgivingmemes', 'amorahkim', 'walmart', 'beauty/american', 'gurts', 'twins', 'outlaw', 'chasetetsuro', 'ilovethem…', 'obsessed…', 'uw', 'inhale']
#    text: i love thanksgivingmemes amorahkim walmart beauty/american gurts twins outlaw chasetetsuro ilovethem… obsessed… uw inhale
#
# Sampling smoothing with alpha=0.01 and with start sequence ['<s>', 'i', 'love']
# 1. ['<s>', 'i', 'love', '&amp', ';', '2017', 'conejovalleydays', 'herowod', 'backstage', 'peer', 'jennnafaa', 'profile_vision…', 'mangodavis', 'briannascafidi', 'popcorn']
#    text: i love &amp ; 2017 conejovalleydays herowod backstage peer jennnafaa profile_vision… mangodavis briannascafidi popcorn
# 2. ['<s>', 'i', 'love', 'so', 'many', 'rip', 'qr', 'legarcias', 'instagood', 'ilovesushi', 'bought…', 'muscletruffles', 'lessons', 'fcuk', 'fullness']
#    text: i love so many rip qr legarcias instagood ilovesushi bought… muscletruffles lessons fcuk fullness
# 3. ['<s>', 'i', 'love', 'wine', 'jonniwithoutthedreadz', '└a', 'julian', 'detergent', 'saltandpeppercrab…', 'p_leezy…', 'chopsticks', 'kittens', 'salud', 'hagel', 'notcominghome']
#    text: i love wine jonniwithoutthedreadz └a julian detergent saltandpeppercrab… p_leezy… chopsticks kittens salud hagel notcominghome
# 4. ['<s>', 'i', 'love', 'much', 'now', '<unk>', 'rudolph', 'badmoms', 'suicidesquad', "'merica", 'triarchydenim', 'chestnut', 'tad', 'minigolf', 'follow…']
#    text: i love much now <unk> rudolph badmoms suicidesquad 'merica triarchydenim chestnut tad minigolf follow…
# 5. ['<s>', 'i', 'love', 'obstacle', 'about…', 'millersburg', 'wildcraft', 'dshampine…', 'unbelievable', 'stalker', 'vegasnights…', 'therealaudience', 'karlkani', 'conditions', 'carshow']
#    text: i love obstacle about… millersburg wildcraft dshampine… unbelievable stalker vegasnights… therealaudience karlkani conditions carshow
#
# ================================================================================
# Starting sequence: ['<s>', 'he', 'likes']
#
# Greedy with start sequence ['<s>', 'he', 'likes']
# 1. ['<s>', 'he', 'likes', 'to', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.', '.']
#    text: he likes to the best friend . . . . . . . .
# 2. ['<s>', 'he', 'likes', 'to', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.', '.']
#    text: he likes to the best friend . . . . . . . .
# 3. ['<s>', 'he', 'likes', 'to', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.', '.']
#    text: he likes to the best friend . . . . . . . .
# 4. ['<s>', 'he', 'likes', 'to', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.', '.']
#    text: he likes to the best friend . . . . . . . .
# 5. ['<s>', 'he', 'likes', 'to', 'the', 'best', 'friend', '.', '.', '.', '.', '.', '.', '.', '.']
#    text: he likes to the best friend . . . . . . . .
#
# Sampling with start sequence ['<s>', 'he', 'likes']
# 1. ['<s>', 'he', 'likes', 'no', 'lifeguards', '?', 'getting', 'it', 'any', 'last', 'night', 'at', 'downtown', 'los', 'angeles']
#    text: he likes no lifeguards ? getting it any last night at downtown los angeles
# 2. ['<s>', 'he', 'likes', 'what', 'i', 'want', 'to', 'come', 'home', '.', 'the', 'little', 'one', '<unk>', 'makes']
#    text: he likes what i want to come home . the little one <unk> makes
# 3. ['<s>', 'he', 'likes', 'fried', 'chicken', 'nuggets', 'thousand', 'winning', 'would', 'be', 'back', 'mixtape', 'droppin', 'em', '!']
#    text: he likes fried chicken nuggets thousand winning would be back mixtape droppin em !
# 4. ['<s>', 'he', 'likes', 'ya', 'top10', 'things', '.', "we've", 'been', 'telling', 'you', 'casa', 'de', 'young', 'love']
#    text: he likes ya top10 things . we've been telling you casa de young love
# 5. ['<s>', 'he', 'likes', 'fruit', 'on…', '</s>']
#    text: he likes fruit on…
#
# Sampling smoothing with alpha=1.0 and with start sequence ['<s>', 'he', 'likes']
# 1. ['<s>', 'he', 'likes', 'orchid', '*****vip', 'batteries', 'stewart…', 'theatrenight…', 'showinglove', '•california', 'loveeeeee', 'audiotechnica', 'stateside', 'gazing', 'stylists…']
#    text: he likes orchid *****vip batteries stewart… theatrenight… showinglove •california loveeeeee audiotechnica stateside gazing stylists…
# 2. ['<s>', 'he', 'likes', 'famiglia', 'allie', 'sapsciencedistillates', 'mamaandthefish…', 'guild', 'bridalshower', 'rcc', 'peacefully', 'stumbled', 'voltaire', 'moonbase', 'dirtybird']
#    text: he likes famiglia allie sapsciencedistillates mamaandthefish… guild bridalshower rcc peacefully stumbled voltaire moonbase dirtybird
# 3. ['<s>', 'he', 'likes', 'teresita', 'up⁇', 'empowerment', 'hairbyconnie', 'bodyrocc', 'blackpanther', 'homies', "gooz's", 'jh', 'model/', 'clarion', 'longbeachcomiccon']
#    text: he likes teresita up⁇ empowerment hairbyconnie bodyrocc blackpanther homies gooz's jh model/ clarion longbeachcomiccon
# 4. ['<s>', 'he', 'likes', 'clippers', 'recipe…', 'desserts', 'sumer', 'primetones…', 'nerds', 'crafted', "applecookie's", 'lance…', 'steamed', 'teamodyssey…', '365grateful…']
#    text: he likes clippers recipe… desserts sumer primetones… nerds crafted applecookie's lance… steamed teamodyssey… 365grateful…
# 5. ['<s>', 'he', 'likes', 'spiderman', 'cellulite', 'scored', 'oddmarketla', 'madilynbelle', 'fortheculture…', '2001/2002', "jessica's", 'supportive', 'board…', 'cardiak…', 'sitka']
#    text: he likes spiderman cellulite scored oddmarketla madilynbelle fortheculture… 2001/2002 jessica's supportive board… cardiak… sitka
#
# Sampling smoothing with alpha=0.1 and with start sequence ['<s>', 'he', 'likes']
# 1. ['<s>', 'he', 'likes', 'salon', '*****vip', 'deepthroat', 'musicmajors', 'chirashi', 'hesgotmewrappedaroundhisfinger', 'doomsday', 'own…', 'missionmountains', 'sunsets…', 'britneylive', 'olives']
#    text: he likes salon *****vip deepthroat musicmajors chirashi hesgotmewrappedaroundhisfinger doomsday own… missionmountains sunsets… britneylive olives
# 2. ['<s>', 'he', 'likes', 'lander', 'mess…', "jumper's", 'another…', 'clueless', 'thriller', 'snohomish', 'njtola', '2989reppin', 'specific…', '-------------------------------------------thattravelblog', 'eventplanners']
#    text: he likes lander mess… jumper's another… clueless thriller snohomish njtola 2989reppin specific… -------------------------------------------thattravelblog eventplanners
# 3. ['<s>', 'he', 'likes', 'speedway', 'weightloss…', 'neonnature', 'them', '08', 'photosbylakeela', 'lumiere', 'question-', 'spa…', 'undercut', 'otus_thaikitchen', 'quintessential']
#    text: he likes speedway weightloss… neonnature them 08 photosbylakeela lumiere question- spa… undercut otus_thaikitchen quintessential
# 4. ['<s>', 'he', 'likes', 'kyliejenner', 'hotbabes', 'union…', 'barefoot', 'dow', 'ealinmotowntour2', 'ashtanga', '20…', 'aurelio', 'coffeepeople', 'late', '11-year-old']
#    text: he likes kyliejenner hotbabes union… barefoot dow ealinmotowntour2 ashtanga 20… aurelio coffeepeople late 11-year-old
# 5. ['<s>', 'he', 'likes', 'lunchbreak', 'leelinbakery…', 'matches', 'a5ern', 'giggles', 'melia', 'garion', 'felishatolentino', 'dallas', 'heceta', 'litaf', 'handcuff']
#    text: he likes lunchbreak leelinbakery… matches a5ern giggles melia garion felishatolentino dallas heceta litaf handcuff
#
# Sampling smoothing with alpha=0.01 and with start sequence ['<s>', 'he', 'likes']
# 1. ['<s>', 'he', 'likes', 'ben', 'former', 'oscars', 'reeds', 'circuitparty', 'tussauds', 'obi', 'popsugarlife…', 'favoraintfair', 'daneinla', "stacy's", 'eve-']
#    text: he likes ben former oscars reeds circuitparty tussauds obi popsugarlife… favoraintfair daneinla stacy's eve-
# 2. ['<s>', 'he', 'likes', 'happygirl', "could've", 'minarets', 'remideroflove', 'treeofakind', 'github', 'dlrcpspring17', 'figuring', 'add', "mary's", 'weiner7733', 'ptd']
#    text: he likes happygirl could've minarets remideroflove treeofakind github dlrcpspring17 figuring add mary's weiner7733 ptd
# 3. ['<s>', 'he', 'likes', 'me', 'and', 'just', 'helper', 'magic', 'venice', 'jayollerophotography', 'european', 'sparkeventconsulting', 'topshop', 'clothing', 'casitas']
#    text: he likes me and just helper magic venice jayollerophotography european sparkeventconsulting topshop clothing casitas
# 4. ['<s>', 'he', 'likes', 'lance', 'laceemup', '••••', 'alloro', 'creatingnewmemories', 'alfredcoffee', 'ride…', 'balifornia', 'feels', 'like', 'in', 'the']
#    text: he likes lance laceemup •••• alloro creatingnewmemories alfredcoffee ride… balifornia feels like in the
# 5. ['<s>', 'he', 'likes', 'concrete', 'lamakiabylaw', 'womensmarchslo', 'choreography…', 'seescandies', 'pacificbeach', 'sac-con', 'beautifulwife…', '*´꒳`*', 'healthylifestyle', 'drawn', 'kohlslife']
#    text: he likes concrete lamakiabylaw womensmarchslo choreography… seescandies pacificbeach sac-con beautifulwife… *´꒳`* healthylifestyle drawn kohlslife

# %% [markdown]
# Generation methods without start sequence:
# - The Greedy is fully deterministic: all 5 outputs are the same. In our case it produced the same high-frequency path (`i love you ...`) and then a high number of punctuation tokens (`.`), which seems reasonable for a bigram model.
# - Sampling without smoothing is different. The outputs are all different, sometimes end early with `</s>`, and can include token chains that makes no ses or with `<unk>`.
# - Sampling with smoothing changes how coherent it is based on `alpha`:
#   - `alpha = 1.0`: noisy outputs with many unusual tokens
#   - `alpha = 0.1`: still unusual, but slightly better than `alpha=1.0`.
#   - `alpha = 0.01`: closest to the unsmoothed model, still diverse but it's a bit more context respecting.
#
# Generation with starting sequences using 3 different prompts:
# - The model correctly keeps the provided prefix (e.g., `["<s>", "you", "can"]`, `["<s>", "i", "love"]`, `["<s>", "he", "likes"]`).
# - Greedy gives the same output every time.
# - Sampling gives different continuations for every prefix, so it catches uncertainty better.
# - Sampling with smoothing keeps the prefix but, for larger `alpha` values, quickly goes to rare or unseen tokens while smaller `alpha` balances context and diversity better.
#
# Overall, the greedy is stable but repetitive, while the other sampling-based methods are more different, and high smoothing increases randomness.

# %% [markdown]
# ## 4. Perplexity
#
# In this section, we will implement and use perplexity as the metric that will help us judge which language model is the best. For this we will first calculate probabilities of each token in a sequence, depending on the previous tokens. For numerical stability, we will actually use logarithms of probabilities.

# %% [markdown]
# <a name='e15'></a>
# ### Exercise 15: Calculate sequence probabilities
#
# (4p) Fill the following function to calculate the logarithms of probabilities of each token in a sequence of tokens. Apply smoothing when calculating the probability. You can first calculate the probability (with smoothing) and then apply `numpy.log()` function.

# %%
def calculate_total_logprob_smoothing(tokens, language_model, smoothing=0.0):
    logprobs = np.zeros(len(tokens), dtype=float)
    for i in range(0, len(tokens)):
        previous_tokens = tokens[:i]
        current_token = tokens[i]
        counts =  language_model.get_counts(previous_tokens)
        denominator = np.sum(counts) + smoothing * language_model.vocab_size

        token_idx = language_model.word_to_index.get(current_token)
        if token_idx is None:
          token_idx = language_model.word_to_index.get('<unk>')

        numerator = (counts[token_idx] if token_idx is not None else 0) + smoothing

        if denominator == 0 or numerator <= 0:
          logprobs[i] = -np.inf
        else:
          logprobs[i] = np.log(numerator / denominator)


    total_logprob = logprobs.sum()
    return total_logprob

# %% [markdown]
# <a name='e16'></a>
# ### Exercise 16: Calculate sentence perplexity
#
# (4p) In this exercise, you will use the function above to calculate the perplexity. Consult the slides for the formulation that depends on the logarithm of probability.

# %%
def calculate_perplexity(tokens, languge_model, smoothing=0.0):
    total_logprob = calculate_total_logprob_smoothing(tokens, languge_model, smoothing)
    # since perpexlity is defined per token divide by sequence length
    n_tokens =  len(tokens)

    if n_tokens == 0:
      return np.inf

    # if any tokens probability is 0 logprob is -inf and perpexlity is infinite
    if not np.isfinite(total_logprob):
      return np.inf

    perplexity = np.exp(-total_logprob / n_tokens)
    return perplexity

# %% [markdown]
# We can test our function:

# %%
tokens = dataset['train'][0]['tokens']
print(tokens)

perplexity = calculate_perplexity(tokens, bigram_lm, smoothing=0.1)
print(perplexity)
# Out:
# ['<s>', 'sunday', 'afternoon', 'walking', 'through', 'venice', 'in', 'the', 'sun', 'with', 'abbot', 'kinney', ',', 'venice', '</s>']
# 1028.6434207150173

# %% [markdown]
# <a name='e17'></a>
# ### Exercise 17: Perplexity of sentences
# (4p) Calculate perplexities of several (at least 5) sentences of your choice. Try different values of smoothing. Discuss the results: do the perplexities align with what you expected?

# %%
smoothings = [1, 1.1, 1.2, 0.9, 0.8, 10, 0.1]

for i in range(1, 6):
  print(dataset['train'][i]['text'])
  tokens = dataset['train'][i]['tokens']
  print(tokens)
  for j in smoothings:
    perplexity = calculate_perplexity(tokens, bigram_lm, smoothing=j)
    print(perplexity)
# Out:
# time for some bbq and whiskey libations . chomp , belch , chomp ! ( lucille's smokehouse bar-b-que )
# ['<s>', 'time', 'for', 'some', 'bbq', 'and', 'whiskey', 'libations', '.', 'chomp', ',', 'belch', ',', 'chomp', '!', '(', "lucille's", 'smokehouse', 'bar-b-que', ')', '</s>']
# 9027.881171801951
# 9506.341921460347
# 9956.22191421628
# 8517.014873791264
# 7969.066105517585
# 23330.43365540155
# 2199.8434619730206
# love love love all these people friends bff celebrate blessed sundayfunday san…
# ['<s>', 'love', 'love', 'love', 'all', 'these', 'people', 'friends', 'bff', 'celebrate', 'blessed', 'sundayfunday', 'san…', '</s>']
# 5234.942343529473
# 5566.761759267945
# 5884.049056650478
# 4886.83514649554
# 4520.306022603496
# 18343.91469818352
# 1049.130782584088
# toys " r " us
# ['<s>', 'toys', '"', 'r', '"', 'us', '</s>']
# 23366.760702167845
# 24319.706043927472
# 25195.086732661828
# 22323.82674363191
# 21175.32154411374
# 43008.03888474305
# 6905.390745703691
# man these are the funniest kids ever ! ! that face ! happybirthdaybubb flipnout xtreme
# ['<s>', 'man', 'these', 'are', 'the', 'funniest', 'kids', 'ever', '!', '!', 'that', 'face', '!', 'happybirthdaybubb', 'flipnout', 'xtreme', '</s>']
# 5550.414483381504
# 5887.314266354664
# 6209.442332064067
# 5196.980375905975
# 4824.854813705926
# 18459.06479992679
# 1256.8884255982907
# sandiego san diego , california
# ['<s>', 'sandiego', 'san', 'diego', ',', 'california', '</s>']
# 545.1925278772112
# 583.4651944103431
# 620.9500009556314
# 506.0474430129218
# 465.9234571431243
# 2816.7315393478602
# 131.15933877436657

# %% [markdown]
# Generallly a lower smoothing appears to also give a lower perplexity rate, this is completely reasonable since with a lower smoothing value the model trusts the training data more, basically saying if it sees a word paired frequently it gives high confidence. This leads to the inevitable lower perplexity rate since it is very confident in its choiches made.

# %% [markdown]
# <a name='e18'></a>
# ### Exercise 18: Perplexity of the whole dataset
#
# (4p) Now we will calculate the perplexity of the entire dataset (or a subset). The function you will implement should calculate the logarithms of probabilities and the lengths of each of the sequences in the dataset. We need both to correctly calculate the perplexity per token.

# %%
def calculate_perplexity_dataset(dataset, languge_model, smoothing=0.0):
    all_logprobs = []
    all_lengths = []

    # iterate over each entry calculate its log-probability and add it to the list
    for example in dataset:
        tokens = example['tokens']

        total_logprob = calculate_total_logprob_smoothing(tokens, languge_model, smoothing)

        all_logprobs.append(total_logprob)
        all_lengths.append(len(tokens))

    total_logprob_sum = sum(all_logprobs)
    total_tokens = sum(all_lengths)

    # sanity checks
    if total_tokens == 0:
        return np.inf

    if not np.isfinite(total_logprob_sum):
        return np.inf

    perplexity = np.exp(-total_logprob_sum / total_tokens)

    return perplexity

# %% [markdown]
# Now, let's calculate the perplexity of the validation dataset.

# %%
validation_perplexity = calculate_perplexity_dataset(dataset['validation'], bigram_lm, smoothing=0.1 )
print('validation perplexity', validation_perplexity)
# Out:
# validation perplexity 1757.5852132463476

# %% [markdown]
# ## 5. Comparing Language Models
# In this final section, you will use all of the above to evaluate different models against each other. While this is a single exercise, you are expected add as many code and markdown cells as you wish. You can plot the results, add tables, etc.

# %% [markdown]
# The models should be evaluated on the `test` subset of the dataset. None of the models should have "seen" it during training and any hyperparameter tuning (if applicable). Below, you can see how we can use our function `calculate_perplexity_dataset()` to calculate the perplexity:

# %%
test_perplexity = calculate_perplexity_dataset(dataset['test'], bigram_lm, smoothing=0.1)
print('test perplexity', test_perplexity)
# Out:
# test perplexity 1676.901745604999

# %% [markdown]
# This could take couple of minutes. To test your code you can select a subset of this dataset. But make sure to report the final results in the exercise below on the full test set.

# %%
test_1000_perplexity = calculate_perplexity_dataset(dataset['test'].select(range(1000)), bigram_lm, smoothing=0.1)
print('test (1000 examples) perplexity', test_1000_perplexity)
# Out:
# test (1000 examples) perplexity 1647.8452106554212

# %% [markdown]
# <a name='e19'></a>
# ### Exercise 19: More Advanced Language Model
# (20p) In this exercise, implement either an interpolation or backoff language model that combines more than one n-gram counter.
# Make sure to adjust weights based on the perplexity of the validation dataset.
# Compare the tuned model with previous models on the test set. Include n-grams with different values of n.
# Discuss the results.
#
# #### Requirements:
# - create n-gram language models with higher values of n,
# - implement at least one more advanced (combining multiple n-grams) language model,
# - tune its weights on the `validation` subset,
# - compare the model(s) against the basic models,
# - discuss the results (Are the results as expected? Why? Why not? etc.)

# %%
# trigram model
trigrams = calculate_ngrams(dataset['train'], 3)
trigram_lm = NgramLanguageModel(trigrams, 3, vocab)
print(f"trigram model: {len(trigrams)} trigrams")

# 4 gram model
fourgrams = calculate_ngrams(dataset['train'], 4)
fourgram_lm = NgramLanguageModel(fourgrams, 4, vocab)
print(f"4 gram model {len(fourgrams)} 4-grams")
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 32154.40it/s]
# 100%|██████████| 405238/405238 [00:00<00:00, 536605.46it/s]
# trigram model: 405238 trigrams
# 100%|██████████| 45000/45000 [00:01<00:00, 32396.50it/s]
# 100%|██████████| 447359/447359 [00:00<00:00, 623234.50it/s]
# 4 gram model 447359 4-grams

# %% [markdown]
# A more advanced language model calculates the probability by using a weighted sum, so we can take the ngramlanguage model class and tweak it into an combined one

# %%
class AdvancedLanguageModel:
    """
    An advanced language model that combines multiple n-gram models.

    The probability is calculated as a weighted sum:
    P(w|context) = λ₁*P₁(w|context) + λ₂*P₂(w|context) + ...

    Attributes:
        models: list of NgramLanguageModel objects
        weights: list of interpolation weights
        vocab: list of unique tokens in the language
     """
    def __init__(self, models, weights, vocab):

        # Some assertions (weights add up to 1, cant be negative, needs to equal the amnt of models)
        assert len(models) == len(weights)
        assert abs(sum(weights) - 1.0) < 1e-6
        assert all(w >= 0 for w in weights)

        self.models = models
        self.weights = weights
        self.vocab = vocab
        self.word_to_index = {word: i for i, word in enumerate(vocab)}
        self.vocab_size = len(vocab)
        self.n = max(model.n for model in models)  # Maximum n among all models

    def get_counts(self, previous_tokens):
        """
        Get advanced counts (weighted sum of counts from all models)

        Args:
            previous_tokens: the sequence of tokens seen so far

        Returns: an integer np.ndarray of shape (vocab_size,) where the value at index 'i' is the count of vocab[i] following the context.
        """
        advanced_counts = np.zeros(self.vocab_size, dtype=float)

        for model, weight in zip(self.models, self.weights):
            counts = model.get_counts(previous_tokens)

            # add weighted contribution
            total_count = counts.sum()
            if total_count > 0:
                probs = (counts + 1) / (total_count + self.vocab_size)
            else:
                probs = np.ones(self.vocab_size) / self.vocab_size

            # Scale back to count-like values
            advanced_counts += weight * probs * 1000

        return advanced_counts

# %%
unigram_lm_test = NgramLanguageModel(calculate_ngrams(dataset['train'], 1), 1, vocab)
bigram_lm_test = NgramLanguageModel(calculate_ngrams(dataset['train'], 2), 2, vocab)
trigram_lm_test = NgramLanguageModel(calculate_ngrams(dataset['train'], 3), 3, vocab)
fourgram_lm_test = NgramLanguageModel(calculate_ngrams(dataset['train'], 4), 4, vocab)

# Example weights for testing (sum to 1)
example_weights = [0.1, 0.2, 0.3, 0.4] # for unigram, bigram, trigram, fourgram

advanced_lm = AdvancedLanguageModel(
    models=[unigram_lm_test, bigram_lm_test, trigram_lm_test, fourgram_lm_test],
    weights=example_weights,
    vocab=vocab
)


# Test get_counts with a sample previous_tokens
sample_previous_tokens = ["<s>", "you", "can"]
combined_counts = advanced_lm.get_counts(sample_previous_tokens)

print(f"\nCombined counts for context {sample_previous_tokens}:\n{combined_counts}")

# To verify, you could check the sum or specific indices
print(f"Sum of combined counts: {np.sum(combined_counts)}")
print(f"Shape of combined counts: {combined_counts.shape}")
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 27316.88it/s]
# 100%|██████████| 50003/50003 [00:00<00:00, 2090608.79it/s]
# 100%|██████████| 45000/45000 [00:01<00:00, 27613.46it/s]
# 100%|██████████| 247981/247981 [00:00<00:00, 1346456.08it/s]
# 100%|██████████| 45000/45000 [00:01<00:00, 27458.33it/s]
# 100%|██████████| 405238/405238 [00:00<00:00, 419444.48it/s]
# 100%|██████████| 45000/45000 [00:01<00:00, 26493.45it/s]
# 100%|██████████| 447359/447359 [00:00<00:00, 580135.90it/s]
# Combined counts for context ['<s>', 'you', 'can']:
# [3.47655217 2.48783461 1.96372129 ... 1.69213188 6.52523337 6.52523337]
# Sum of combined counts: 999.9999999999998
# Shape of combined counts: (50003,)
